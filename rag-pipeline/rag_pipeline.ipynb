# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.graph_stores.neo4j import Neo4jPGStore
import os
from dotenv import load_dotenv

load_dotenv()

username = os.getenv('NEO4J_USERNAME')
password = os.getenv('NEO4J_PASSWORD')
url = os.getenv('NEO4J_URL')

graph_store = Neo4jPGStore(
    username=username,
    password=password,
    url=url,
)
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The procedure has a deprecated field. ('config' used by 'apoc.meta.graphSample' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: "CALL apoc.meta.graphSample() YIELD nodes, relationships RETURN nodes, [rel in relationships | {name:apoc.any.property(rel, 'type'), count: apoc.any.property(rel, 'count')}] AS relationships"

# %%
import os

os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %%
import pandas as pd
from llama_index.core import Document

news = pd.read_csv("https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/news_articles.csv")
documents = [Document(text=f"{row['title']}: {row['text']}") for i, row in news.iterrows()]
news.head()
# Out:
#                                                title  \
# 0                             Chevron: Best Of Breed
# 1       FirstEnergy (NYSE:FE) Posts Earnings Results
# 2  Dáil almost suspended after Sinn Féin TD put p...
# 3  Epic’s latest tool can animate hyperrealistic ...
# 4  EU to Ban Huawei, ZTE from Internal Commission...
#
#                                   date  \
# 0  2031-04-06T01:36:32.000000000+00:00
# 1  2030-04-29T06:55:28.000000000+00:00
# 2  2023-06-15T14:32:11.000000000+00:00
# 3  2023-06-15T14:00:00.000000000+00:00
# 4  2023-06-15T13:50:00.000000000+00:00
#
#                                                 text
# 0  JHVEPhoto Like many companies in the O&G secto...
# 1  FirstEnergy (NYSE:FE – Get Rating) posted its ...
# 2  The Dáil was almost suspended on Thursday afte...
# 3  Today, Epic is releasing a new tool designed t...
# 4  The European Commission is planning to ban equ...

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4o", temperature=0.0)
embed_model = OpenAIEmbedding(model_name="text-embedding-3-small")

# %%
from typing import Literal
from llama_index.core.indices.property_graph import SchemaLLMPathExtractor

# best practice to use upper-case
entities = Literal["PERSON", "LOCATION", "ORGANIZATION", "PRODUCT", "EVENT"]
relations = Literal[
    "SUPPLIER_OF",
    "COMPETITOR",
    "PARTNERSHIP",
    "ACQUISITION",
    "WORKS_AT",
    "SUBSIDIARY",
    "BOARD_MEMBER",
    "CEO",
    "PROVIDES",
    "HAS_EVENT",
    "IN_LOCATION",
]

# %%
# define which entities can have which relations
validation_schema = {
    "Person": ["WORKS_AT", "BOARD_MEMBER", "CEO", "HAS_EVENT"],
    "Organization": [
        "SUPPLIER_OF",
        "COMPETITOR",
        "PARTNERSHIP",
        "ACQUISITION",
        "WORKS_AT",
        "SUBSIDIARY",
        "BOARD_MEMBER",
        "CEO",
        "PROVIDES",
        "HAS_EVENT",
        "IN_LOCATION",
    ],
    "Product": ["PROVIDES"],
    "Event": ["HAS_EVENT", "IN_LOCATION"],
    "Location": ["HAPPENED_AT", "IN_LOCATION"],
}

# %%
from llama_index.core import PropertyGraphIndex

kg_extractor = SchemaLLMPathExtractor(
    llm=llm,
    possible_entities=entities,
    possible_relations=relations,
    kg_validation_schema=validation_schema,
    # if false, allows for values outside of the schema
    # useful for using the schema as a suggestion
    strict=True,
)

NUMBER_OF_ARTICLES = 250

index = PropertyGraphIndex.from_documents(
    documents[:NUMBER_OF_ARTICLES],
    kg_extractors=[kg_extractor],
    llm=llm,
    embed_model=embed_model,
    property_graph_store=graph_store,
    show_progress=True,
)
# Out:
# Parsing nodes: 100%|██████████| 250/250 [00:00<00:00, 2326.02it/s]
# Extracting paths from text with schema:  24%|██▍       | 61/250 [01:16<03:06,  1.01it/s]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.10506541233035316 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29878, Requested 896. Please try again in 1.548s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  25%|██▌       | 63/250 [01:20<04:27,  1.43s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.8273630725821677 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29503, Requested 896. Please try again in 798ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  30%|██▉       | 74/250 [01:36<03:48,  1.30s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.16842395478356553 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29327, Requested 765. Please try again in 184ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  33%|███▎      | 83/250 [01:50<04:35,  1.65s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.23126766834977408 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29492, Requested 983. Please try again in 950ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  34%|███▎      | 84/250 [01:50<03:49,  1.38s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.647249445841108 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29902, Requested 983. Please try again in 1.77s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  38%|███▊      | 95/250 [02:09<03:15,  1.26s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.4153905404972845 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29847, Requested 992. Please try again in 1.678s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  42%|████▏     | 105/250 [02:26<03:29,  1.45s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.0998330917910425 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29895, Requested 937. Please try again in 1.664s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 0.08545986264749339 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29821, Requested 1011. Please try again in 1.664s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  43%|████▎     | 107/250 [02:32<05:22,  2.26s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 1.2580909120068255 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29478, Requested 1011. Please try again in 977ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 0.1582464905786959 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29576, Requested 956. Please try again in 1.064s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  48%|████▊     | 120/250 [02:54<03:39,  1.69s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.24121416844579058 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29510, Requested 835. Please try again in 690ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  59%|█████▉    | 148/250 [03:38<02:31,  1.49s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.510000257200483 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29514, Requested 921. Please try again in 870ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  60%|██████    | 150/250 [03:43<03:14,  1.94s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 1.8459932554450607 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29542, Requested 921. Please try again in 926ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  61%|██████    | 153/250 [03:49<03:09,  1.96s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.3118396070115965 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29669, Requested 1078. Please try again in 1.494s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  62%|██████▏   | 156/250 [03:54<02:27,  1.57s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.7580809054047917 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29578, Requested 701. Please try again in 558ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  75%|███████▌  | 188/250 [04:45<01:17,  1.25s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.4731463591888959 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29946, Requested 952. Please try again in 1.796s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 0.5989110464463965 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29308, Requested 863. Please try again in 342ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  82%|████████▏ | 205/250 [05:13<00:58,  1.30s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.9928866288575082 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29674, Requested 952. Please try again in 1.252s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  83%|████████▎ | 208/250 [05:19<01:06,  1.59s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.5948946396034301 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29664, Requested 716. Please try again in 760ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  84%|████████▍ | 210/250 [05:22<01:04,  1.61s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.8251117962980761 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29755, Requested 716. Please try again in 941ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  87%|████████▋ | 217/250 [05:33<00:51,  1.55s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.12293469502566012 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29785, Requested 715. Please try again in 1s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  88%|████████▊ | 219/250 [05:37<00:55,  1.78s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.24079534349441978 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29681, Requested 799. Please try again in 960ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  88%|████████▊ | 221/250 [05:40<00:46,  1.59s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.3767010336486136 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29481, Requested 970. Please try again in 902ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  89%|████████▉ | 223/250 [05:43<00:40,  1.50s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.010679582124025533 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29606, Requested 970. Please try again in 1.152s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  91%|█████████ | 228/250 [05:52<00:37,  1.69s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.22348877615229867 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29512, Requested 896. Please try again in 816ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  93%|█████████▎| 233/250 [06:01<00:27,  1.60s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.05290044014014539 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29827, Requested 692. Please try again in 1.038s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  96%|█████████▌| 239/250 [06:11<00:15,  1.38s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.044324712339511074 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29541, Requested 555. Please try again in 192ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  96%|█████████▋| 241/250 [06:13<00:11,  1.30s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 1.7289198092941738 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29804, Requested 555. Please try again in 718ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema:  97%|█████████▋| 243/250 [06:16<00:09,  1.30s/it]Retrying llama_index.llms.openai.base.OpenAI._achat in 0.5272857433614742 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-OxQFpyLWgSN1Jf6A5aXj9wI4 on tokens per min (TPM): Limit 30000, Used 29874, Requested 783. Please try again in 1.314s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Extracting paths from text with schema: 100%|██████████| 250/250 [06:30<00:00,  1.56s/it]
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: id)} {position: line: 1, column: 19, offset: 18} for query: "MATCH (e) WHERE e.id in $ids \n        WITH e\n        RETURN e.id AS name,\n               [l in labels(e) WHERE l <> '__Entity__' | l][0] AS type,\n               e{.* , embedding: Null, id: Null} AS properties\n        "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: id)} {position: line: 3, column: 18, offset: 62} for query: "MATCH (e) WHERE e.id in $ids \n        WITH e\n        RETURN e.id AS name,\n               [l in labels(e) WHERE l <> '__Entity__' | l][0] AS type,\n               e{.* , embedding: Null, id: Null} AS properties\n        "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: id)} {position: line: 1, column: 19, offset: 18} for query: "MATCH (e) WHERE e.id in $ids \n        WITH e\n        RETURN e.id AS name,\n               [l in labels(e) WHERE l <> '__Entity__' | l][0] AS type,\n               e{.* , embedding: Null, id: Null} AS properties\n        "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: id)} {position: line: 3, column: 18, offset: 62} for query: "MATCH (e) WHERE e.id in $ids \n        WITH e\n        RETURN e.id AS name,\n               [l in labels(e) WHERE l <> '__Entity__' | l][0] AS type,\n               e{.* , embedding: Null, id: Null} AS properties\n        "
# Generating embeddings: 100%|██████████| 3/3 [00:01<00:00,  2.24it/s]
# Generating embeddings: 100%|██████████| 46/46 [00:03<00:00, 13.06it/s]
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The procedure has a deprecated field. ('config' used by 'apoc.meta.graphSample' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: "CALL apoc.meta.graphSample() YIELD nodes, relationships RETURN nodes, [rel in relationships | {name:apoc.any.property(rel, 'type'), count: apoc.any.property(rel, 'count')}] AS relationships"

# %%
graph_store.structured_query("""
CREATE VECTOR INDEX entity IF NOT EXISTS
FOR (m:`__Entity__`)
ON m.embedding
OPTIONS {indexConfig: {
 `vector.dimensions`: 1536,
 `vector.similarity_function`: 'cosine'
}}
""")
# Out:
# []

# %%
# Just for inspection
similarity_threshold = 0.9
word_edit_distance = 5
data = graph_store.structured_query("""
MATCH (e:__Entity__)
CALL {
  WITH e
  CALL db.index.vector.queryNodes('entity', 10, e.embedding)
  YIELD node, score
  WITH node, score
  WHERE score > toFLoat($cutoff)
      AND (toLower(node.name) CONTAINS toLower(e.name) OR toLower(e.name) CONTAINS toLower(node.name)
           OR apoc.text.distance(toLower(node.name), toLower(e.name)) < $distance)
      AND labels(e) = labels(node)
  WITH node, score
  ORDER BY node.name
  RETURN collect(node) AS nodes
}
WITH distinct nodes
WHERE size(nodes) > 1
WITH collect([n in nodes | n.name]) AS results
UNWIND range(0, size(results)-1, 1) as index
WITH results, index, results[index] as result
WITH apoc.coll.sort(reduce(acc = result, index2 IN range(0, size(results)-1, 1) |
        CASE WHEN index <> index2 AND
            size(apoc.coll.intersection(acc, results[index2])) > 0
            THEN apoc.coll.union(acc, results[index2])
            ELSE acc
        END
)) as combinedResult
WITH distinct(combinedResult) as combinedResult
// extra filtering
WITH collect(combinedResult) as allCombinedResults
UNWIND range(0, size(allCombinedResults)-1, 1) as combinedResultIndex
WITH allCombinedResults[combinedResultIndex] as combinedResult, combinedResultIndex, allCombinedResults
WHERE NOT any(x IN range(0,size(allCombinedResults)-1,1)
    WHERE x <> combinedResultIndex
    AND apoc.coll.containsAll(allCombinedResults[x], combinedResult)
)
RETURN combinedResult
""", param_map={'cutoff': similarity_threshold, 'distance': word_edit_distance})
for row in data:
    print(row)
# Out:
# {'combinedResult': ['Stock', 'stock']}
# {'combinedResult': ['firefighters debate', 'firefighters dispute']}
# {'combinedResult': ['MetaHuman', 'MetaHuman Animator']}
# {'combinedResult': ['XPeng', 'XPeng Inc', 'Xpeng']}
# {'combinedResult': ['Bank of America', 'Bank of America Corp.']}
# {'combinedResult': ['tools for rent reporting and data solutions', 'tools for rent reporting and data solutions for credit building']}
# {'combinedResult': ['Hyatt', 'Hyatt Corporation', 'Hyatt Hotels']}
# {'combinedResult': ['Star Ocean', 'Star Ocean 2', 'Star Ocean 2 remake', 'Star Ocean The Second Story', 'Star Ocean: The Second Story', 'Star Ocean: The Second Story R']}
# {'combinedResult': ['logo leak', 'logo leaked']}
# {'combinedResult': ['Star Ocean First Departure R', 'Star Ocean: First Departure R']}
# {'combinedResult': ['support.na.square-enix.com/images/title_banner/title_banner_19285.jpg', 'support.na.square-enix.com/images/title_banner/title_banner_19288.jpg']}
# {'combinedResult': ['Citigroup', 'Citigroup Inc.']}
# {'combinedResult': ['Wells Fargo', 'Wells Fargo & Co.']}
# {'combinedResult': ['JPMorgan', 'JPMorgan Asset Management', 'JPMorgan Chase & Co.']}
# {'combinedResult': ['CarMax Auto Owner Trust 2019-3', 'CarMax Auto Owner Trust 2019-4']}
# {'combinedResult': ['333-228379', '333-228379-03', '333-228379-04']}
# {'combinedResult': ['Newcastle', 'Newcastle United']}
# {'combinedResult': ['Premier League 2023-24', 'Premier League 2023/2024', 'Premier League 2023/24']}
# {'combinedResult': ['4GB + 64GB', '6GB + 128GB']}
# {'combinedResult': ['Press release', 'press release']}
# {'combinedResult': ['IT Taxi', 'IT taxi']}
# {'combinedResult': ['Buy rating', 'Hold rating']}
# {'combinedResult': ['Price Target', 'price target']}
# {'combinedResult': ['Delta Air Lines', 'Delta Air Lines Inc.']}
# {'combinedResult': ['suspended dividend', 'suspended dividend in March 2020']}
# {'combinedResult': ['Baltimore', 'Baltimore Ravens', 'Ravens']}
# {'combinedResult': ['General Motors', 'General Motors Co.']}
# {'combinedResult': ['Ford Motor', 'Ford Motor Co.']}
# {'combinedResult': ['Electric Cars', 'electric-car']}
# {'combinedResult': ['Alibaba', 'Alibaba Group']}
# {'combinedResult': ['Aldeyra', 'Aldeyra Therapeutics']}
# {'combinedResult': ['dividend', 'dividends']}
# {'combinedResult': ['shareholder return', 'total shareholder return']}
# {'combinedResult': ['Share Price', 'share price']}
# {'combinedResult': ['European Commission approval of Rinvoq® for the treatment of Crohn’s disease', 'approval of Rinvoq® for the treatment of Crohn’s disease']}
# {'combinedResult': ['treatment for non-radiographic axial spondyloarthritis', 'treatment for radiographic axial spondyloarthritis']}
# {'combinedResult': ['BBC2', 'BBC4']}
# {'combinedResult': ['New York', 'New York, New York']}
# {'combinedResult': ['Atlas Air', 'Atlas Air Worldwide', 'Atlas Air Worldwide Holdings Inc.']}
# {'combinedResult': ['Goldman Sachs', 'Goldman Sachs Group Inc.']}
# {'combinedResult': ['UTI Asset Management Company', 'UTI Asset Management Company Limited', 'UTI Asset Management Company Ltd']}
# {'combinedResult': ['June 14, 2023', 'June 15 2023']}
# {'combinedResult': ['Zee Entertainment', 'Zee Entertainment Enterprises Ltd.']}
# {'combinedResult': ['replaced Drew Smith', 'replaced by Drew Smith']}
# {'combinedResult': ['Giants', 'New York Giants']}
# {'combinedResult': ['Death', 'death']}
# {'combinedResult': ['Square Enix support site', 'Square Enix support website']}
# {'combinedResult': ['Australian Opposition Party', 'Australian opposition party']}
# {'combinedResult': ['Expels Senator Over Sexual Misconduct Allegations', 'expels senator over sexual misconduct allegations']}
# {'combinedResult': ['BTC Halving', 'Bitcoin Halving', 'Bitcoin Halving 2024']}
# {'combinedResult': ['Tesla Inc', 'Tesla Inc.']}
# {'combinedResult': ['Qualcomm', 'Qualcomm Technologies, Inc.']}
# {'combinedResult': ["European People's Party", 'European People’s Party']}
# {'combinedResult': ['Realme 11 Pro 5G', 'Realme 11 Pro+ 5G']}
# {'combinedResult': ['bullying, harassment and sexual assault', 'harassment and sexual assault']}
# {'combinedResult': ['Quarterly Dividend Increase', 'quarterly dividend increase']}
# {'combinedResult': ['Delhi', 'New Delhi']}
# {'combinedResult': ['Baja California Sur', 'Baja California Sur, Mexico']}
# {'combinedResult': ['Airtel', 'Bharti Airtel']}
# {'combinedResult': ['5G service', '5G services']}
# {'combinedResult': ['32 GB internal storage', '64 GB internal storage']}
# {'combinedResult': ['Smart Hub', 'Smart Hub Plus', 'Smart Hub Plus router']}
# {'combinedResult': ['Smart Wi-Fi', 'Smart Wi-Fi Plus']}
# {'combinedResult': ['Laser World of Photonics', 'Laser World of Photonics China']}
# {'combinedResult': ['Apple Podcasts', 'Google Podcasts']}
# {'combinedResult': ['PH10 SmartWeld+', 'PH20 SmartWeld+']}
# {'combinedResult': ['Real-time Intelligence', 'real-time intelligence']}
# {'combinedResult': ['Stock Market Intelligence', 'stock market intelligence']}
# {'combinedResult': ['Benzinga Pro Community', 'Benzinga Pro community']}
# {'combinedResult': ['Levi & Korsinsky', 'Levi & Korsinsky, LLP']}
# {'combinedResult': ['Class Action Lawsuit', 'Class Action Lawsuit Deadline', 'class action lawsuit']}
# {'combinedResult': ['Legal Services', 'legal services']}
# {'combinedResult': ['City NGP (Navigation Guided Pilot)', 'City NGP (Navigation Guided Pilot) system']}
# {'combinedResult': ['Inditex', 'Inditex SA']}
# {'combinedResult': ['July payment', 'June payment']}
# {'combinedResult': ['GroupM', 'GroupM India', 'GroupM Nexus', 'GroupM South Asia']}
# {'combinedResult': ['11,000 charging points', '800 charging points']}
# {'combinedResult': ['Adani Green Energy', 'Adani Green Energy Limited', 'Adani Green Energy Ltd']}
# {'combinedResult': ['Ranked among the top 10 companies in the world in the Renewable Energy sector by Sustainalytics', 'ranked among the top 10 companies in the world in the renewable energy sector by Sustainalytics']}
# {'combinedResult': ['Fujifilm Instax SQ40', 'Instax SQ40']}
# {'combinedResult': ['Activision Blizzard', 'Activision Blizzard, Inc.']}
# {'combinedResult': ['Nvidia', 'Nvidia Corp.']}
# {'combinedResult': ["Vera's Land Rover", "photo of Vera's Land Rover"]}
# {'combinedResult': ['$1,751', '$1,785']}
# {'combinedResult': ['Maleic Anhydride', 'Maleic Anhydride plant']}
# {'combinedResult': ['Sky Q 1TB UHD box', 'Sky Q 1TB box', 'Sky Q 2TB box']}
# {'combinedResult': ['Adani Enterprises', 'Adani Enterprises Ltd']}
# {'combinedResult': ['Adani Ports', 'Adani Ports & SEZ Ltd']}
# {'combinedResult': ['Adani Total Gas', 'Adani Total Gas Ltd']}
# {'combinedResult': ['Adani Transmission', 'Adani Transmission Ltd']}

# %%
graph_store.structured_query("""
MATCH (e:__Entity__)
CALL {
  WITH e
  CALL db.index.vector.queryNodes('entity', 10, e.embedding)
  YIELD node, score
  WITH node, score
  WHERE score > toFLoat($cutoff)
      AND (toLower(node.name) CONTAINS toLower(e.name) OR toLower(e.name) CONTAINS toLower(node.name)
           OR apoc.text.distance(toLower(node.name), toLower(e.name)) < $distance)
      AND labels(e) = labels(node)
  WITH node, score
  ORDER BY node.name
  RETURN collect(node) AS nodes
}
WITH distinct nodes
WHERE size(nodes) > 1
WITH collect([n in nodes | n.name]) AS results
UNWIND range(0, size(results)-1, 1) as index
WITH results, index, results[index] as result
WITH apoc.coll.sort(reduce(acc = result, index2 IN range(0, size(results)-1, 1) |
        CASE WHEN index <> index2 AND
            size(apoc.coll.intersection(acc, results[index2])) > 0
            THEN apoc.coll.union(acc, results[index2])
            ELSE acc
        END
)) as combinedResult
WITH distinct(combinedResult) as combinedResult
// extra filtering
WITH collect(combinedResult) as allCombinedResults
UNWIND range(0, size(allCombinedResults)-1, 1) as combinedResultIndex
WITH allCombinedResults[combinedResultIndex] as combinedResult, combinedResultIndex, allCombinedResults
WHERE NOT any(x IN range(0,size(allCombinedResults)-1,1)
    WHERE x <> combinedResultIndex
    AND apoc.coll.containsAll(allCombinedResults[x], combinedResult)
)
CALL {
  WITH combinedResult
	UNWIND combinedResult AS name
	MATCH (e:__Entity__ {name:name})
	WITH e
	ORDER BY size(e.name) DESC // prefer longer names to remain after merging
	RETURN collect(e) AS nodes
}
CALL apoc.refactor.mergeNodes(nodes, {properties: {
    `.*`: 'discard'
}})
YIELD node
RETURN count(*)
""", param_map={'cutoff': similarity_threshold, 'distance': word_edit_distance})
# Out:
# [{'count(*)': 90}]

# %% [markdown]
# # custom retriever

# %%
from pydantic import BaseModel
from typing import Optional, List


class Entities(BaseModel):
    """List of named entities in the text such as names of people, organizations, concepts, and locations"""
    names: Optional[List[str]]


prompt_template_entities = """
Extract all named entities such as names of people, organizations, concepts, and locations
from the following text:
{text}
"""

# %%
from typing import Any, Optional

from llama_index.core.embeddings import BaseEmbedding
from llama_index.core.retrievers import CustomPGRetriever, VectorContextRetriever
from llama_index.core.vector_stores.types import VectorStore
from llama_index.program.openai import OpenAIPydanticProgram


class MyCustomRetriever(CustomPGRetriever):
    """Custom retriever with cohere reranking."""

    def init(
        self,
        ## vector context retriever params
        embed_model: Optional[BaseEmbedding] = None,
        vector_store: Optional[VectorStore] = None,
        similarity_top_k: int = 4,
        path_depth: int = 1,
        include_text: bool = True,
        **kwargs: Any,
    ) -> None:
        """Uses any kwargs passed in from class constructor."""
        self.entity_extraction = OpenAIPydanticProgram.from_defaults(
            output_cls=Entities, prompt_template_str=prompt_template_entities
        )
        self.vector_retriever = VectorContextRetriever(
            self.graph_store,
            include_text=self.include_text,
            embed_model=embed_model,
            similarity_top_k=similarity_top_k,
            path_depth=path_depth,
        )

    def custom_retrieve(self, query_str: str) -> str:
        """Define custom retriever with reranking.

        Could return `str`, `TextNode`, `NodeWithScore`, or a list of those.
        """
        entities = self.entity_extraction(text=query_str).names
        result_nodes = []
        if entities:
            print(f"Detected entities: {entities}")
            for entity in entities:
                result_nodes.extend(self.vector_retriever.retrieve(entity))
        else:
            result_nodes.extend(self.vector_retriever.retrieve(query_str))
        ## TMP: please change
        final_text = "\n\n".join(
            [n.get_content(metadata_mode="llm") for n in result_nodes]
        )
        return final_text

# %%
from llama_index.core.query_engine import RetrieverQueryEngine

custom_sub_retriever = MyCustomRetriever(
    index.property_graph_store,
    include_text=True,
    vector_store=index.vector_store,
    embed_model=embed_model
)

query_engine = RetrieverQueryEngine.from_args(
    index.as_retriever(sub_retrievers=[custom_sub_retriever]), llm=llm
)

# %%
# response = query_engine.query("What do you know about Maliek Collins or Darragh O’Brien?")
response = query_engine.query("Do you know anything about Chevron?")
print(str(response))
# Out:
# Detected entities: ['Chevron']
# Chevron is a company listed on the NYSE (New York Stock Exchange) and provides stock and balance sheet information. It has a strong balance sheet and has seen a decline in its stock price by about 10% over the past 90 days, despite a significant rise in Q2 consensus earnings estimates. Additionally, JHVEPhoto is a competitor of Chevron.
